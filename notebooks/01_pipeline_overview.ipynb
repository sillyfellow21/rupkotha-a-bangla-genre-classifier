# %% [markdown]
# # Rupkotha Genre Engine\n
# Bengali transformer-based book genre classification workflow.

# %%
# !python -m src.preprocessing --input_csv data/raw/bengali_books_demo.csv --output_csv data/processed/books_clean.csv

# %%
# !python -m src.eda --input_csv data/processed/books_clean.csv

# %%
# !python -m src.train --input_csv data/processed/books_clean.csv --epochs 3 --batch_size 8

# %%
# !python -m src.evaluate --model_dir model/best_model --test_csv data/processed/test_split.csv
